# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose **Refresh / Content Opportunity Scoring**.
#
# My goal is to identify which content pages should be reviewed first for refreshing or improving. This lane interests me because it combines search performance data with machine learning to help prioritize pages that may benefit from updates. Instead of relying only on fixed rules, I want to use data-driven insights to support better content review decisions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The Question
#
# **Research Question:** Which content pages should be reviewed first based on search visibility and engagement signals?
#
# **Decision:** Decide which pages deserve priority for review.
#
# **Action:** A content reviewer can refresh, improve, expand, or monitor the selected pages.
#
# **Cost of a wrong recommendation:** Recommending the wrong pages wastes review time, while missing important pages can lead to lost traffic and missed improvement opportunities.
#
# **Why ML can help:** Machine learning can combine multiple signals such as impressions, clicks, CTR, content age, and engagement to rank pages more effectively than a simple rule.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Average 90-day impressions:", round(df["impressions_90d"].mean(), 2))
# Out:
# Number of rows: 30000
# Number of columns: 44
# Average CTR: 0.511
# Average 90-day impressions: 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work identifies patterns in anonymized search and content data to support content review decisions.
#
# The results are observational and do not prove that refreshing a page will improve its performance.
#
# The model is intended to help prioritize pages for human review, not replace human judgment or claim causal relationships.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
