# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/sanjanabhat846/sanju.git
# %cd sanju
# !ls
# Out:
# Cloning into 'sanju'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 108 (delta 27), reused 77 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (108/108), 1.84 MiB | 7.97 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# /content/sanju/sanju
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My lane as an ML task
#
# I chose **Refresh / Content Opportunity Scoring**.
#
# This is primarily a **scoring and ranking** machine learning task. The goal is to assign a score to each content page based on its search and engagement signals, then rank the pages so that reviewers know which ones should be reviewed first. Machine learning is useful because it can combine multiple signals more effectively than a simple fixed rule.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or Proxy
#
# The target is to identify content pages that are likely to need review for refresh or improvement.
#
# As a proxy, I will use the trend information available in the starter dataset, such as declining content or low-performing pages. This provides a practical starting point before building stronger future-looking labels in later assignments.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## Success Metric
#
# The success of this task will be measured using ranking metrics such as Precision@K and Average Precision.
#
# A good model should rank the most important pages higher than a simple rule so that reviewers spend their time on the pages with the highest opportunity.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Shape:", df.shape)

df.head()
# Out:
# Shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# Each row in this dataset represents **one content page** with its associated search and engagement metrics. The model will analyze one page at a time and estimate its opportunity for content review.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Why ML beats a fixed rule
#
# A fixed rule considers only a few predefined conditions, while machine learning can combine many observable signals such as impressions, clicks, CTR, content age, and engagement. This allows the model to produce a more flexible and accurate ranking of pages that deserve attention while still supporting human decision making.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
