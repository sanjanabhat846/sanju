# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %%
# !git clone https://github.com/sanjanabhat846/sanju.git
# %cd /content/sanju
# !ls
# Out:
# Cloning into 'sanju'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 123 (delta 40), reused 77 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.84 MiB | 11.57 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# /content/sanju
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     scripts   submission
# CLAUDE.md  docs		notebooks  requirements.txt  SETUP.md  work
# data	   GUIDE.md	outputs    sanju	     skills

# %%
# %cd /content/sanju
# Out:
# /content/sanju

# %% [markdown]
# ## My Rule
#
# I will rank pages that may need a content refresh. The rule gives higher scores to pages that have high search impressions but low CTR or are older content. These pages have the greatest opportunity for improvement because they already receive visibility but may not be attracting enough clicks.
#
# ## Reason Codes
#
# - LOW_CTR – The page has a low click-through rate compared to its visibility.
# - HIGH_IMPRESSIONS – The page receives many impressions, so improving it could have a larger impact.
# - OLD_CONTENT – The content is relatively old and may benefit from updating.
# - REFRESH_RECOMMENDED – The combined signals indicate that this page should be reviewed for a content refresh.
#
# ## Action Label
#
# Refresh Content

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.columns.tolist())
# Out:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
import pandas as pd
import os

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Create a simple baseline score
df["baseline_score"] = (
    df["impressions_90d"] * 0.5
    + (1 - df["ctr"]) * 100
)

# Reason code
df["reason_code"] = "REFRESH_RECOMMENDED"

# Action label
df["action"] = "Refresh Content"

# Sort by score
ranked = df.sort_values("baseline_score", ascending=False)

# Create output folder
os.makedirs("work/outputs", exist_ok=True)

# Save CSV
ranked.to_csv(
    "work/outputs/baseline_action_score.csv",
    index=False
)

print("CSV Saved Successfully!")

ranked.head(10)
# Out:
# CSV Saved Successfully!
#                  content_id          client_id  search_volume  competition  \
# 6653   content_5fe46e04994d  client_4e07408562         1900.0         0.00
# 17812  content_aaef01a50def  client_19581e27de         4400.0         0.05
# 26844  content_8c19996aa890  client_4e07408562           70.0         0.01
# 19636  content_2cb567c3c89b  client_6208ef0f77            0.0         0.00
# 21819  content_4c36c775b818  client_4e07408562           40.0         0.00
# 29400  content_2dba2b1f9536  client_6208ef0f77            0.0         0.00
# 29879  content_1a9e894be2e2  client_19581e27de           70.0         0.07
# 13537  content_2c2606c5d176  client_19581e27de          590.0         0.18
# 18870  content_db5989a78dd3  client_4e07408562          110.0         0.00
# 14090  content_44e481c8f55b  client_19581e27de           20.0         0.26
#
#       competition_level   cpc     content_type    main_intent  word_count  \
# ...

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %% [markdown]
# ## Top 10 Review
#
# 1. Refresh Content – High impressions with relatively low CTR. Could be wrong if the page is already optimized.
# 2. Refresh Content – Receives good visibility but CTR is lower than expected. Could be seasonal traffic.
# 3. Refresh Content – High search demand but limited engagement. Could be due to user intent.
# 4. Refresh Content – Good opportunity because of visibility. Could be wrong if competitors recently changed.
# 5. Refresh Content – Older content with improvement potential. Could already have been updated externally.
# 6. Refresh Content – Large impression count suggests high value. CTR may naturally be lower in this niche.
# 7. Refresh Content – Strong candidate for optimization. Low CTR may result from SERP features.
# 8. Refresh Content – Opportunity for title and meta description improvement. Ranking position may affect CTR.
# 9. Refresh Content – High exposure with limited clicks. Traffic pattern may be temporary.
# 10. Refresh Content – Recommended for review based on the baseline rule. Additional business context may change the priority.

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %%
## Weak Picks

Some pages may receive high baseline scores because they have many impressions, but they may already perform well enough for their purpose.

The rule does not consider search intent, recent content updates, seasonality, or business priorities. Therefore, these pages should be reviewed manually before any action is taken.
# Out:
#   File "/tmp/ipykernel_760/4181910935.py", line 3
#     Some pages may receive high baseline scores because they have many impressions, but they may already perform well enough for their purpose.
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
